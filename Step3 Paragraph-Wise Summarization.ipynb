# %%
import nltk
import spacy
import numpy as np
import pandas as pd
import networkx as nx
from nltk.corpus import stopwords
from sumy.utils import get_stop_words
from sumy.nlp.stemmers import Stemmer
from __future__ import absolute_import
from nltk.tokenize import sent_tokenize
from sumy.parsers.html import HtmlParser
from gensim.summarization import keywords
from sumy.nlp.tokenizers import Tokenizer
from gensim.summarization import summarize
from sumy.summarizers.lsa import LsaSummarizer
from sumy.summarizers.luhn import LuhnSummarizer
from sumy.parsers.plaintext import PlaintextParser
from sklearn.metrics.pairwise import cosine_similarity
from sumy.summarizers.lex_rank import LexRankSummarizer
from sumy.summarizers.edmundson import EdmundsonSummarizer
from __future__ import division, print_function, unicode_literals

# %%
file = "Our_Past_1_Chapter2.txt"

# %%
para_data = [[]]
para_name = ''
chapter_name = ''
EndOfChap = 0
with open(file, encoding="utf8") as f:
    for count, line in enumerate(f):
        if EndOfChap < 2:
            if 'CHAPTER' in line:
                chapter_name = line.split(':')[1].strip()
                continue
                
            if line == '\n':
                para_data.append([])
                EndOfChap +=1
                
            elif para_data[-1] == [] and para_name == '':
                para_name = line
                
            else:
                para_descr = line
                para_data[-1] = [chapter_name, para_name, para_descr]
                para_name = ''
                EndOfChap  = 0
                

para_data = [i for i in para_data if i != []]
for o_index in range(len(para_data)):
    for i_index in range(len(para_data[o_index])):
        para_data[o_index][i_index] = para_data[o_index][i_index].strip()

# %%
df_para = pd.DataFrame(para_data, columns = ['Chapter Name', 'Paragraph Title', 'Description'])
df_para.index = np.arange(1,len(df_para)+1)

# %%
df_para.head(5)
# Out:
#                              Chapter Name  \
# 1  FROM HUNTING-GATHERING TO GROWING FOOD
# 2  FROM HUNTING-GATHERING TO GROWING FOOD
# 3  FROM HUNTING-GATHERING TO GROWING FOOD
# 4  FROM HUNTING-GATHERING TO GROWING FOOD
# 5  FROM HUNTING-GATHERING TO GROWING FOOD
#
#                                     Paragraph Title  \
# 1                            Tushar’s train journey
# 2  The earliest people: why were they on the move ?
# 3                 How do we know about this place ?
# 4                         Choose a place to live in
# 5              Rock paintings and what they tell us
#
#                                          Description
# 1  Tushar was going from Delhi to Chennai for his...
# 2  We know about people who lived in the subconti...
# 3  Archaeologists have found some of the things h...
# 4  Look at Map 2 below. All the places marked wit...
# 5  Many of the caves in which these early people ...

# %%
def remove_stopwords(sen):
    stop_words = stopwords.words('english')
    sen_new = " ".join([i for i in sen if i not in stop_words])
    return sen_new

def Custom_Summary(sentences,n):
    #print('No. of Sents: ',len(sentences))
    word_embeddings = {}
    sentence_vectors = []
    summary = ''
    #print('Loading Word Embeddings...')
    
    f1 = open('glove.6B.100d.txt', encoding='utf-8')
    for line in f1:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        word_embeddings[word] = coefs
    f.close()
    #print('Word Embeddings Loaded...')
    
    clean_sentences = pd.Series(sentences).str.strip().replace("[^a-zA-Z]", " ")   
    clean_sentences = [s.lower() for s in clean_sentences]
    stop_words = stopwords.words('english')
    clean_sentences = [remove_stopwords(r.split()) for r in clean_sentences]
    #print('Sentence Cleaning Completed....')
    
    for i in clean_sentences:
        if len(i) != 0:
            v = sum([word_embeddings.get(w, np.zeros((100,))) for w in i.split()])/(len(i.split())+0.001)
        else:
            v = np.zeros((100,))
        sentence_vectors.append(v)
    #print('Vectorization Completed....')
    
    sim_mat = np.zeros([len(sentences), len(sentences)])
    for i in range(len(sentences)):
        for j in range(len(sentences)):
            if i != j:
                sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,100), sentence_vectors[j].reshape(1,100))[0,0]
    #print('Similarity Mattrix Formed....')
    
    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph)
    ranked_sentences = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)
    #print('Graph Formed....')
    for i in range(n):
        summary = summary + ranked_sentences[i][1] + ' '

    return summary.strip()

# %%
def Gensim_Summary(sentences,ratio):
    contents = ' '.join(sentences)
    return summarize(contents, ratio=ratio)

# %%
def LexRank_Summary(sentences,n):
    LANG = "english"
    ans = ''
    contents = ' '.join(sentences)
    parser = PlaintextParser.from_string(contents, Tokenizer(LANG))
    summarizer = LexRankSummarizer()
    summary = summarizer(parser.document, n) 
    for sentence in summary:
        ans = ans + str(sentence) + ' '
    return ans

# %%
def Luhn_Summary(sentences,n):
    LANG = "english"
    ans = ''
    contents = ' '.join(sentences)
    parser = PlaintextParser.from_string(contents, Tokenizer(LANG))
    summarizer = LuhnSummarizer()
    summary = summarizer(parser.document, n) 
    for sentence in summary:
        ans = ans + str(sentence) + ' '
    return ans

# %%
def LSA_Summary(sentences,n):
    LANG = "english"
    ans = ''
    contents = ' '.join(sentences)
    parser = PlaintextParser.from_string(contents, Tokenizer(LANG))
    summarizer = LsaSummarizer()
    summary = summarizer(parser.document, n) 
    for sentence in summary:
        ans = ans + str(sentence) + ' '
    return ans

# %%
def make_sent(text_data):
    sents = nltk.sent_tokenize(text_data)
    return sents

# %%
df_summarized = df_para
df_summarized['Sentence List'] = df_para['Description'].apply(make_sent)

# %%
df_summarized['Custom Summarizer'] = df_summarized['Sentence List'].apply(Custom_Summary, args = (3,))
df_summarized['Gensim Summarizer'] = df_summarized['Sentence List'].apply(Gensim_Summary, args = (0.4,))
df_summarized['LexRank Summarizer'] = df_summarized['Sentence List'].apply(LexRank_Summary, args = (3,))
df_summarized['Luhn Summarizer'] = df_summarized['Sentence List'].apply(Custom_Summary, args = (3,))
df_summarized['LSA Summarizer'] = df_summarized['Sentence List'].apply(LSA_Summary, args = (3,))

# %%
df_summarized
# Out:
#                               Chapter Name  \
# 1   FROM HUNTING-GATHERING TO GROWING FOOD
# 2   FROM HUNTING-GATHERING TO GROWING FOOD
# 3   FROM HUNTING-GATHERING TO GROWING FOOD
# 4   FROM HUNTING-GATHERING TO GROWING FOOD
# 5   FROM HUNTING-GATHERING TO GROWING FOOD
# 6   FROM HUNTING-GATHERING TO GROWING FOOD
# 7   FROM HUNTING-GATHERING TO GROWING FOOD
# 8   FROM HUNTING-GATHERING TO GROWING FOOD
# 9   FROM HUNTING-GATHERING TO GROWING FOOD
# 10  FROM HUNTING-GATHERING TO GROWING FOOD
# 11  FROM HUNTING-GATHERING TO GROWING FOOD
# 12  FROM HUNTING-GATHERING TO GROWING FOOD
# 13  FROM HUNTING-GATHERING TO GROWING FOOD
# 14  FROM HUNTING-GATHERING TO GROWING FOOD
# 15  FROM HUNTING-GATHERING TO GROWING FOOD
# 16  FROM HUNTING-GATHERING TO GROWING FOOD
# 17  FROM HUNTING-GATHERING TO GROWING FOOD
# 18  FROM HUNTING-GATHERING TO GROWING FOOD
# 19  FROM HUNTING-GATHERING TO GROWING FOOD
#
#                                      Paragraph Title  \
# 1                             Tushar’s train journey
# 2   The earliest people: why were they on the move ?
# 3                  How do we know about this place ?
# 4                          Choose a place to live in
# 5               Rock paintings and what they tell us
# 6                                              Sites
# 7                             Finding out about fire
# 8                                    Names and dates
# 9                             A changing environment
# 10              The beginning of farming and herding
# 11                                     Domestication
# 12                                 A new way of life
# 13                                   Storing Animals
# 14   Finding out about the first farmers and herders
# 15                            Towards a settled life
# 16       A closer look - Living and dying in Mehgarh
# 17                           Cave painting in France
# 18                                 A Neolitchic site
# 19                                           Imagine
#
#                                           Description  \
# 1   Tushar was going from Delhi to Chennai for his...
# 2   We know about people who lived in the subconti...
# 3   Archaeologists have found some of the things h...
# 4   Look at Map 2 below. All the places marked wit...
# 5   Many of the caves in which these early people ...
# 6   Sites are places where the remains of things (...
# 7   Find the Kurnool caves on Map 2 (page13). Trac...
# 8   Archaeologists have given lengthy names for th...
# 9   Around 12,000 years ago, there were major chan...
# 10  This was also a time when several grain bearin...
# 11  Domestication is the name given to the process...
# 12  If you plant a seed, you will notice that it t...
# 13  Animals multiply naturally. Besides, if they a...
# 14  Turn to Map 2 (page13). You will notice a numb...
# 15  Archaeologists have found traces of huts or ho...
# 16  Find Mehrgarh on Map 2 (page13). This site is ...
# 17  Find France in your atlas. The painting below ...
# 18  Find Turkey in your atlas. One of the most fam...
# 19  You live in a rock shelter like the one shown ...
#
#                                         Sentence List  \
# 1   [Tushar was going from Delhi to Chennai for hi...
# 2   [We know about people who lived in the subcont...
# 3   [Archaeologists have found some of the things ...
# 4   [Look at Map 2 below., All the places marked w...
# 5   [Many of the caves in which these early people...
# 6   [Sites are places where the remains of things ...
# 7   [Find the Kurnool caves on Map 2 (page13)., Tr...
# 8   [Archaeologists have given lengthy names for t...
# 9   [Around 12,000 years ago, there were major cha...
# 10  [This was also a time when several grain beari...
# 11  [Domestication is the name given to the proces...
# 12  [If you plant a seed, you will notice that it ...
# 13  [Animals multiply naturally., Besides, if they...
# 14  [Turn to Map 2 (page13)., You will notice a nu...
# 15  [Archaeologists have found traces of huts or h...
# 16  [Find Mehrgarh on Map 2 (page13)., This site i...
# 17  [Find France in your atlas., The painting belo...
# 18  [Find Turkey in your atlas., One of the most f...
# 19  [You live in a rock shelter like the one shown...
#
#                                     Custom Summarizer  \
# 1   As he watched trees and houses fly past, his u...
# 2   Second, animals move from place to place — eit...
# 3   It is likely that people made and used tools o...
# 4   All the places marked with red triangles are s...
# 5   Many of the caves in which these early people ...
# 6   These may be found on the surface of the earth...
# 7   Fire could have been used for many things: as ...
# 8   Very often, we use present day names of the pl...
# 9   It is likely that this helped people to start ...
# 10  People could also attract and then tame animal...
# 11  Very often, plants and animals that are tended...
# 12  When people began growing plants, it meant tha...
# 13  What are animals used for today? In other word...
# 14  They can also identify the bones of different ...
# 15  Besides, they began weaving cloth, using diffe...
# 16  In one instance, the dead person was buried wi...
# 17  Or perhaps they were made for special rituals,...
# 18  Several things were brought from great distanc...
# 19  You live in a rock shelter like the one shown ...
#
#                                     Gensim Summarizer  \
# 1   As he watched trees and houses fly past, his u...
# 2   Generally, they hunted wild animals, caught fi...
# 3   Other tools were used to chop wood, which was ...
# 4   All the places marked with red triangles are s...
# 5
# 6   You will learn more about different sites in l...
# 7
# 8   The Palaeolithic period extends from 2 million...
# 9
# 10  People could also attract and then tame animal...
# 11  Domestication is the name given to the process...
# 12  When people began growing plants, it meant tha...
# 13  In other words, animals that are reared can be...
# 14  To find out whether these sites were settlemen...
# 15  Archaeologists have found traces of huts or ho...
# 16  Mehrgarh was probably one of the places where ...
# 17  The painting below is from a cave in France.\n...
# 18  Several things were brought from great distanc...
# 19  Your uncle is painting one of the inner walls ...
#
#                                    LexRank Summarizer  \
# 1   Tushar was going from Delhi to Chennai for his...
# 2   Therefore, they would have had to go elsewhere...
# 3   Archaeologists have found some of the things h...
# 4   Look at Map 2 below. All the places marked wit...
# 5   Many of the caves in which these early people ...
# 6   Sites are places where the remains of things (...
# 7   Find the Kurnool caves on Map 2 (page13). Trac...
# 8   The name points to the importance of finds of ...
# 9   Around 12,000 years ago, there were major chan...
# 10  Men, women and children probably collected the...
# 11  Domestication is the name given to the process...
# 12  If you plant a seed, you will notice that it t...
# 13  Animals multiply naturally. Besides, if they a...
# 14  Turn to Map 2 (page13). To find out whether th...
# 15  Many of these are different from the earlier P...
# 16  Mehrgarh was probably one of the places where ...
# 17  Find France in your atlas. The painting below ...
# 18  Find Turkey in your atlas. One of the most fam...
# 19  You live in a rock shelter like the one shown ...
#
#                                       Luhn Summarizer  \
# 1   As he watched trees and houses fly past, his u...
# 2   Second, animals move from place to place — eit...
# 3   It is likely that people made and used tools o...
# 4   All the places marked with red triangles are s...
# 5   Many of the caves in which these early people ...
# 6   These may be found on the surface of the earth...
# 7   Fire could have been used for many things: as ...
# 8   Very often, we use present day names of the pl...
# 9   It is likely that this helped people to start ...
# 10  People could also attract and then tame animal...
# 11  Very often, plants and animals that are tended...
# 12  When people began growing plants, it meant tha...
# 13  What are animals used for today? In other word...
# 14  They can also identify the bones of different ...
# 15  Besides, they began weaving cloth, using diffe...
# 16  In one instance, the dead person was buried wi...
# 17  Or perhaps they were made for special rituals,...
# 18  Several things were brought from great distanc...
# 19  You live in a rock shelter like the one shown ...
#
#                                        LSA Summarizer
# 1   Tushar was going from Delhi to Chennai for his...
# 2   Therefore, they would have had to go elsewhere...
# 3   Archaeologists have found some of the things h...
# 4   All the places marked with red triangles are s...
# 5   Many of the caves in which these early people ...
# 6   Sites are places where the remains of things (...
# 7   This suggests that people were familiar with t...
# 8   Archaeologists have given lengthy names for th...
# 9   In many areas, this led to the development of ...
# 10  This was also a time when several grain bearin...
# 11  For example, they select those plants and anim...
# 12  This may be for several days, weeks, months an...
# 13  Besides, if they are looked after carefully, t...
# 14  Each marks a site from where archaeologists ha...
# 15  Mortars and pestles are used for grinding grai...
# 16  Other finds at Mehrgarh include remains of squ...
# 17  This site was discovered by four school childr...
# 18  One of the most famous Neolithic sites, Catal ...
# 19  You live in a rock shelter like the one shown ...

# %%
df_summarized.to_csv('Paragraph-Wise Summarization.csv')

# %%
df_summarized['Luhn Summarizer'][2]
# Out:
# 'Second, animals move from place to place — either in search of smaller prey, or, in the case of deer and wild cattle, in search of grass and leaves. People living on their banks would have had to go in search of water during the dry seasons (winter and summer). First, if they had stayed at one place for a long time, they would have eaten up all the available plant and animal resources.'

# %%
df_summarized['LSA Summarizer'][2]
# Out:
# 'Therefore, they would have had to go elsewhere in search of food. That is why those who hunted them had to follow their movements. People living on their banks would have had to go in search of water during the dry seasons (winter and summer). '
