# %% [markdown]
# # Keyword Extraction

# %%
import spacy
import yake
import nltk
import string
import numpy as np
import pandas as pd
from rake_nltk import Rake
from keybert import KeyBERT
from string import punctuation
from collections import Counter
from gensim.summarization import keywords

# %%
# Single paragraph (Para 2 of Ch 2)

text = 'Archaeologists have found some of the things hunter-gatherers made and used. It is likely that people made and used tools of stone, wood and bone, of which stone tools have survived best. Some of these stone tools were used to cut meat and bone, scrape bark (from trees) and hides (animal skins), chop fruit and roots. Some may have been attached to handles of bone or wood, to make spears and arrows for hunting. Other tools were used to chop wood, which was used as firewood. Wood was also used to make huts and tools.'
text = text.translate(str.maketrans('', '', string.punctuation))
file = "C:\\Users\\Viral Doshi\\Desktop\\Viral Academic\\IIT Bombay Intern\\Attempt 1\\Our_Past_1_Chapter2.txt"

# %% [markdown]
# ### Method 1: Spacy Keyword Extraction: Grammar based Method
# #### Extracting Certain parts of speech

# %%
# Method 1: Spacy Keyword Extraction 

def spacy_kw_ext(text):
    nlp = spacy.load("en_core_web_lg")
    result = []
    pos_tag = ['PROPN', 'ADJ', 'NOUN']
    doc = nlp(text.lower())
    for token in doc:
        if(token.text in nlp.Defaults.stop_words):
            continue
        if(token.pos_ in pos_tag):
            result.append(token.text)

    final_kw =  [(x[0]) for x in Counter(result).most_common(10)]
    return final_kw

# %% [markdown]
# ### Method 2: Yake Keyword Extraction: Statistical Method
# ##### Based on Statistical Features

# %%
# Method 2: Yake Keyword Extraction 

def yake_kw_ext(text):
    kw_extractor = yake.KeywordExtractor()
    final_kw = []
    language = "en"
    max_ngram_size = 1
    deduplication_threshold = 0.9
    numOfKeywords = 10
    custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)
    keywords = custom_kw_extractor.extract_keywords(text)
    for kw in keywords[::-1]:
        final_kw.append(kw[0])
    return final_kw

# %% [markdown]
# ### Method 3: Rake NLTK Keyword Extraction
# #### Frequency of Words

# %%
# Method 3: Rake NLTK Keyword Extraction

def rakenltk_kw_ext(text):
    rake_nltk_var = Rake(min_length=1, max_length=1)
    rake_nltk_var.extract_keywords_from_text(text)
    keyword_extracted = rake_nltk_var.get_ranked_phrases()
    return keyword_extracted[:10]

# %% [markdown]
# ### Method 4: Gensim Keyword Extraction
# #### Based on Textrank Algorithm

# %%
# Method 4: Gensim Keyword Extraction

def gensim_kw_ext(text):
    k = keywords(text, words = 10, lemmatize = True,).split('\n')
    final_kw = []
    for i in k:
        final_kw+=i.split(' ')
    return final_kw

# %% [markdown]
# ### Method 5: KeyBert + distilbert base nli mean tokens
# #### Using a Pre-trained Model with max-sum for ranking

# %%
# Method 5: KeyBert + distilbert base nli mean tokens

def KeyBert_distilbert(text):
    kw = []
    kw_model = KeyBERT('distilbert-base-nli-mean-tokens')
    keywords = kw_model.extract_keywords(text)
    temp = kw_model.extract_keywords(text, keyphrase_ngram_range=(1,1), stop_words='english', use_maxsum=True, top_n=10, diversity=0.2, nr_candidates = 20)
    for i in temp:
        kw.append(i[0])
    return kw

# %% [markdown]
# ### Method 6: KeyBert + paraphrase
# #### Using another pre-trained Model + Max-sum + higher diversity measure

# %%
# Method 6: KeyBert + paraphrase

def KeyBert_paraphrase(text):
    kw = []
    kw_model = KeyBERT(model='xlm-r-distilroberta-base-paraphrase-v1')
    keywords = kw_model.extract_keywords(text)
    temp = kw_model.extract_keywords(text, keyphrase_ngram_range=(1,1), stop_words='english', use_maxsum=True, diversity=0.7, top_n = 10)
    for i in temp:
        kw.append(i[0])
    return kw

# %%
data = []
a = spacy_kw_ext(text)
b = yake_kw_ext(text)
c = rakenltk_kw_ext(text)
d = gensim_kw_ext(text)
e = KeyBert_distilbert(text)
f = KeyBert_paraphrase(text)
for i in range(10):
    data.append([a[i], b[i], c[i], d[i], e[i], f[i]])

# %% [markdown]
# ### Visualizing all 6 Methods and checking their results on Para 2

# %%
df = pd.DataFrame(data, columns=["Spacy", "Yake", "RakeNLTK", "Gensim", "Keybert-distilbert", "Keybert-paraphrase"])
df.index = np.arange(1, len(df) + 1)
df = df.style.set_properties(**{'text-align': 'left'})

display(df)
# Out:
# <style  type="text/css" >
# #T_18c13_row0_col0,#T_18c13_row0_col1,#T_18c13_row0_col2,#T_18c13_row0_col3,#T_18c13_row0_col4,#T_18c13_row0_col5,#T_18c13_row1_col0,#T_18c13_row1_col1,#T_18c13_row1_col2,#T_18c13_row1_col3,#T_18c13_row1_col4,#T_18c13_row1_col5,#T_18c13_row2_col0,#T_18c13_row2_col1,#T_18c13_row2_col2,#T_18c13_row2_col3,#T_18c13_row2_col4,#T_18c13_row2_col5,#T_18c13_row3_col0,#T_18c13_row3_col1,#T_18c13_row3_col2,#T_18c13_row3_col3,#T_18c13_row3_col4,#T_18c13_row3_col5,#T_18c13_row4_col0,#T_18c13_row4_col1,#T_18c13_row4_col2,#T_18c13_row4_col3,#T_18c13_row4_col4,#T_18c13_row4_col5,#T_18c13_row5_col0,#T_18c13_row5_col1,#T_18c13_row5_col2,#T_18c13_row5_col3,#T_18c13_row5_col4,#T_18c13_row5_col5,#T_18c13_row6_col0,#T_18c13_row6_col1,#T_18c13_row6_col2,#T_18c13_row6_col3,#T_18c13_row6_col4,#T_18c13_row6_col5,#T_18c13_row7_col0,#T_18c13_row7_col1,#T_18c13_row7_col2,#T_18c13_row7_col3,#T_18c13_row7_col4,#T_18c13_row7_col5,#T_18c13_row8_col0,#T_18c13_row8_col1,#T_18c13_row8_col2,#T_18c13_row8_col3,#T_18c13_row8_col4,#T_18c13_row8_col5,#T_18c13_row9_col0,#T_18c13_row9_col1,#T_18c13_row9_col2,#T_18c13_row9_col3,#T_18c13_row9_col4,#T_18c13_row9_col5{
#             text-align:  left;
#         }</style><table id="T_18c13_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Spacy</th>        <th class="col_heading level0 col1" >Yake</th>        <th class="col_heading level0 col2" >RakeNLTK</th>        <th class="col_heading level0 col3" >Gensim</th>        <th class="col_heading level0 col4" >Keybert-distilbert</th>        <th class="col_heading level0 col5" >Keybert-paraphrase</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18c13_level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_18c13_row0_col0" class="data row0 col0" >tools</td>
#                         <td id="T_18c13_row0_col1" class="data row0 col1" >things</td>
#                         <td id="T_18c13_row0_col2" class="data row0 col2" >wood</td>
#                         <td id="T_18c13_row0_col3" class="data row0 col3" >scrape</td>
#                         <td id="T_18c13_row0_col4" class="data row0 col4" >fruit</td>
#                         <td id="T_18c13_row0_col5" class="data row0 col5" >bark</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_18c13_row1_col0" class="data row1 col0" >wood</td>
#                         <td id="T_18c13_row1_col1" class="data row1 col1" >found</td>
#                         <td id="T_18c13_row1_col2" class="data row1 col2" >used</td>
#                         <td id="T_18c13_row1_col3" class="data row1 col3" >stone</td>
#                         <td id="T_18c13_row1_col4" class="data row1 col4" >trees</td>
#                         <td id="T_18c13_row1_col5" class="data row1 col5" >used</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_18c13_row2_col0" class="data row2 col0" >stone</td>
#                         <td id="T_18c13_row2_col1" class="data row2 col1" >Archaeologists</td>
#                         <td id="T_18c13_row2_col2" class="data row2 col2" >trees</td>
#                         <td id="T_18c13_row2_col3" class="data row2 col3" >wood</td>
#                         <td id="T_18c13_row2_col4" class="data row2 col4" >stone</td>
#                         <td id="T_18c13_row2_col5" class="data row2 col5" >skins</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row3" class="row_heading level0 row3" >4</th>
#                         <td id="T_18c13_row3_col0" class="data row3 col0" >bone</td>
#                         <td id="T_18c13_row3_col1" class="data row3 col1" >chop</td>
#                         <td id="T_18c13_row3_col2" class="data row3 col2" >tools</td>
#                         <td id="T_18c13_row3_col3" class="data row3 col3" >animal</td>
#                         <td id="T_18c13_row3_col4" class="data row3 col4" >arrows</td>
#                         <td id="T_18c13_row3_col5" class="data row3 col5" >trees</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row4" class="row_heading level0 row4" >5</th>
#                         <td id="T_18c13_row4_col0" class="data row4 col0" >archaeologists</td>
#                         <td id="T_18c13_row4_col1" class="data row4 col1" >make</td>
#                         <td id="T_18c13_row4_col2" class="data row4 col2" >roots</td>
#                         <td id="T_18c13_row4_col3" class="data row4 col3" >skins</td>
#                         <td id="T_18c13_row4_col4" class="data row4 col4" >bone</td>
#                         <td id="T_18c13_row4_col5" class="data row4 col5" >arrows</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row5" class="row_heading level0 row5" >6</th>
#                         <td id="T_18c13_row5_col0" class="data row5 col0" >things</td>
#                         <td id="T_18c13_row5_col1" class="data row5 col1" >made</td>
#                         <td id="T_18c13_row5_col2" class="data row5 col2" >may</td>
#                         <td id="T_18c13_row5_col3" class="data row5 col3" >chop</td>
#                         <td id="T_18c13_row5_col4" class="data row5 col4" >meat</td>
#                         <td id="T_18c13_row5_col5" class="data row5 col5" >cut</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row6" class="row_heading level0 row6" >7</th>
#                         <td id="T_18c13_row6_col0" class="data row6 col0" >huntergatherers</td>
#                         <td id="T_18c13_row6_col1" class="data row6 col1" >bone</td>
#                         <td id="T_18c13_row6_col2" class="data row6 col2" >likely</td>
#                         <td id="T_18c13_row6_col3" class="data row6 col3" >things</td>
#                         <td id="T_18c13_row6_col4" class="data row6 col4" >hunting</td>
#                         <td id="T_18c13_row6_col5" class="data row6 col5" >firewood</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row7" class="row_heading level0 row7" >8</th>
#                         <td id="T_18c13_row7_col0" class="data row7 col0" >likely</td>
#                         <td id="T_18c13_row7_col1" class="data row7 col1" >stone</td>
#                         <td id="T_18c13_row7_col2" class="data row7 col2" >hunting</td>
#                         <td id="T_18c13_row7_col3" class="data row7 col3" >huntergatherers</td>
#                         <td id="T_18c13_row7_col4" class="data row7 col4" >firewood</td>
#                         <td id="T_18c13_row7_col5" class="data row7 col5" >archaeologists</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row8" class="row_heading level0 row8" >9</th>
#                         <td id="T_18c13_row8_col0" class="data row8 col0" >people</td>
#                         <td id="T_18c13_row8_col1" class="data row8 col1" >wood</td>
#                         <td id="T_18c13_row8_col2" class="data row8 col2" >handles</td>
#                         <td id="T_18c13_row8_col3" class="data row8 col3" >cut</td>
#                         <td id="T_18c13_row8_col4" class="data row8 col4" >archaeologists</td>
#                         <td id="T_18c13_row8_col5" class="data row8 col5" >hunting</td>
#             </tr>
#             <tr>
#                         <th id="T_18c13_level0_row9" class="row_heading level0 row9" >10</th>
#                         <td id="T_18c13_row9_col0" class="data row9 col0" >meat</td>
#                         <td id="T_18c13_row9_col1" class="data row9 col1" >tools</td>
#                         <td id="T_18c13_row9_col2" class="data row9 col2" >found</td>
#                         <td id="T_18c13_row9_col3" class="data row9 col3" >meat</td>

# %% [markdown]
# ### --------- X ---------

# %% [markdown]
# ### All are working pretty well ! Let's apply all these methods to Full Chapter

# %%
para_data = [[]]
para_name = ''
chapter_name = ''
EndOfChap = 0
with open(file, encoding="utf8") as f:
    for count, line in enumerate(f):
        if EndOfChap < 2:
            if 'CHAPTER' in line:
                chapter_name = line.split(':')[1].strip()
                continue
                
            if line == '\n':
                para_data.append([])
                EndOfChap +=1
                
            elif para_data[-1] == [] and para_name == '':
                para_name = line
                
            else:
                para_descr = line
                para_data[-1] = [chapter_name, para_name, para_descr]
                para_name = ''
                EndOfChap  = 0
                

para_data = [i for i in para_data if i != []]
for o_index in range(len(para_data)):
    for i_index in range(len(para_data[o_index])):
        para_data[o_index][i_index] = para_data[o_index][i_index].strip()

# %%
a = []
count = 0
sent_data = []
para_name = ''
chapter_name = ''
EndOfChap = 0
newpara = False

nlp = spacy.load("en_core_web_sm")
with open(file, encoding="utf8") as f:
    for line in f:
        a.append(line)

for index,line in enumerate(a):
    if EndOfChap < 2:
        if 'CHAPTER' in line:
            chapter_name = line.split(':')[1].strip()
            continue
            
        if line == '\n':
            para_name = ''
            newpara = True
            EndOfChap +=1
            continue
        
        if newpara and para_name == '':
            para_name = line.strip()
            newpara = False
            continue
            
        if not newpara:
            doc = nlp(a[index])
            for sent in doc.sents:
                fsent = str(sent).strip()
                sent_data.append([chapter_name,para_name,fsent])
            EndOfChap  = 0

# %%
df_sent = pd.DataFrame(sent_data, columns = ['Chapter Name', 'Paragraph Title', 'Sentence'])
df_para = pd.DataFrame(para_data, columns = ['Chapter Name', 'Paragraph Title', 'Description'])
df_sent.index = np.arange(1,len(df_sent)+1)
df_para.index = np.arange(1,len(df_para)+1)

# %%
df_para['Description'] = df_para['Description'].apply(lambda text: text.translate(str.maketrans('', '', string.punctuation)))

# %%
df_para['Spacy'] = df_para['Description'].apply(spacy_kw_ext)
df_para['Yake'] = df_para['Description'].apply(yake_kw_ext)
df_para['RakeNLTK'] = df_para['Description'].apply(rakenltk_kw_ext)
df_para['Gensim'] = df_para['Description'].apply(gensim_kw_ext)
df_para['Keybert-distilbert'] = df_para['Description'].apply(KeyBert_distilbert)
df_para['Keybert-paraphrase'] = df_para['Description'].apply(KeyBert_paraphrase)

# %% [markdown]
# ## Let's have a look at the Final Dataframe with proper para-wise data and the Extracted Keywords from those paragraphs

# %%
df_para
# Out:
#                               Chapter Name  \
# 1   FROM HUNTING-GATHERING TO GROWING FOOD
# 2   FROM HUNTING-GATHERING TO GROWING FOOD
# 3   FROM HUNTING-GATHERING TO GROWING FOOD
# 4   FROM HUNTING-GATHERING TO GROWING FOOD
# 5   FROM HUNTING-GATHERING TO GROWING FOOD
# 6   FROM HUNTING-GATHERING TO GROWING FOOD
# 7   FROM HUNTING-GATHERING TO GROWING FOOD
# 8   FROM HUNTING-GATHERING TO GROWING FOOD
# 9   FROM HUNTING-GATHERING TO GROWING FOOD
# 10  FROM HUNTING-GATHERING TO GROWING FOOD
# 11  FROM HUNTING-GATHERING TO GROWING FOOD
# 12  FROM HUNTING-GATHERING TO GROWING FOOD
# 13  FROM HUNTING-GATHERING TO GROWING FOOD
# 14  FROM HUNTING-GATHERING TO GROWING FOOD
# 15  FROM HUNTING-GATHERING TO GROWING FOOD
# 16  FROM HUNTING-GATHERING TO GROWING FOOD
# 17  FROM HUNTING-GATHERING TO GROWING FOOD
# 18  FROM HUNTING-GATHERING TO GROWING FOOD
# 19  FROM HUNTING-GATHERING TO GROWING FOOD
#
#                                      Paragraph Title  \
# 1                             Tushar’s train journey
# 2   The earliest people: why were they on the move ?
# 3                  How do we know about this place ?
# 4                          Choose a place to live in
# 5               Rock paintings and what they tell us
# 6                                              Sites
# 7                             Finding out about fire
# 8                                    Names and dates
# 9                             A changing environment
# 10              The beginning of farming and herding
# 11                                     Domestication
# 12                                 A new way of life
# 13                                   Storing Animals
# 14   Finding out about the first farmers and herders
# 15                            Towards a settled life
# 16       A closer look - Living and dying in Mehgarh
# 17                           Cave painting in France
# 18                                 A Neolitchic site
# 19                                           Imagine
#
#                                           Description  \
# 1   Tushar was going from Delhi to Chennai for his...
# 2   We know about people who lived in the subconti...
# 3   Archaeologists have found some of the things h...
# 4   Look at Map 2 below All the places marked with...
# 5   Many of the caves in which these early people ...
# 6   Sites are places where the remains of things t...
# 7   Find the Kurnool caves on Map 2 page13 Traces ...
# 8   Archaeologists have given lengthy names for th...
# 9   Around 12000 years ago there were major change...
# 10  This was also a time when several grain bearin...
# 11  Domestication is the name given to the process...
# 12  If you plant a seed you will notice that it ta...
# 13  Animals multiply naturally Besides if they are...
# 14  Turn to Map 2 page13 You will notice a number ...
# 15  Archaeologists have found traces of huts or ho...
# 16  Find Mehrgarh on Map 2 page13 This site is loc...
# 17  Find France in your atlas The painting below i...
# 18  Find Turkey in your atlas One of the most famo...
# 19  You live in a rock shelter like the one shown ...
#
#                                                 Spacy  \
# 1   [tushar, people, delhi, chennai, cousin, weddi...
# 2   [place, search, people, water, animals, plants...
# 3   [tools, wood, stone, bone, archaeologists, thi...
# 4   [places, map, sites, stone, red, triangles, ar...
# 5   [paintings, pradesh, caves, early, people, wal...
# 6   [sites, earth, places, remains, things, tools,...
# 7   [fire, kurnool, caves, map, page13, traces, as...
# 8   [years, names, time, period, stone, tools, pal...
# 9   [animals, years, major, changes, climate, worl...
# 10  [animals, people, food, animal, wild, dog, tim...
# 11  [plants, animals, domestication, wild, people,...
# 12  [grain, seed, time, people, plants, pots, days...
# 13  [animals, food, milk, important, source, meat,...
# 14  [number, evidence, farmers, herders, subcontin...
# 15  [people, tools, different, food, things, archa...
# 16  [mehrgarh, people, bones, site, sheep, goats, ...
# 17  [france, years, paintings, wild, colours, atla...
# 18  [turkey, things, cowries, sea, shells, atlas, ...
# 19  [colours, rock, shelter, page14, years, uncle,...
#
#                                                  Yake  \
# 1   [squeeze, managed, travelling, wedding, cousin...
# 2   [hunted, food, moved, huntergatherers, animals...
# 3   [things, found, Archaeologists, chop, make, ma...
# 4   [found, archaeologists, triangles, red, marked...
# 5   [walls, lived, people, early, caves, skill, pa...
# 6   [buildings, pots, tools, things, remains, plac...
# 7   [suggests, found, ash, caves, today, Find, Kur...
# 8   [places, called, Neolithic, period, tools, tim...
# 9   [shift, world, climate, major, ago, important,...
# 10  [animal, Men, lived, wild, food, grew, dog, ta...
# 11  [earliest, result, people, Seeds, select, wild...
# 12  [till, birds, plants, pots, began, people, tim...
# 13  [milk, provide, carefully, looked, naturally, ...
# 14  [identify, burnt, bones, found, subcontinent, ...
# 15  [thousand, grinding, mortars, Archaeologists, ...
# 16  [Bolan, Map, goats, site, sheep, Burial, found...
# 17  [atlas, reasons, Find, colours, wild, Painting...
# 18  [things, Remember, Mediterranean, Red, Syria, ...
# 19  [walls, painting, uncle, ago, shown, shelter, ...
#
#                                              RakeNLTK  \
# 1   [’, wedding, tushar, travelling, trains, train...
# 2   [would, way, water, summer, subcontinent, stay...
# 3   [wood, used, trees, tools, roots, may, likely,...
# 4   [water, sites, shown, rivers, places, many, lo...
# 5              [walls, skill, paintings, many, caves]
# 6   [water, surface, sites, remains, places, peopl...
# 7   [used, use, today, suggests, source, people, l...
# 8   [wood, use, time, think, studying, sickles, sa...
# 9   [world, survived, shift, rearing, number, like...
# 10  [time, think, tamed, shelters, ripened, reason...
# 11  [world, wheat, weight, use, tended, teeth, sow...
# 12  [ways, time, think, takes, storing, stored, st...
# 13  [used, today, things, reared, obtained, looked...
# 14  [whether, turn, subcontinent, sites, site, set...
# 15  [used, tools, suggests, sites, remember, quite...
# 16  [wheat, used, storage, square, site, sheep, se...
# 17  [went, think, site, search, reasons, prey, pos...
# 18  [used, people, found, cattle, carried, brought...
# 19  [want, uncle, stories, page14, mix, live, help...
#
#                                                Gensim  \
# 1   [people, fly, later, tushar, glass, pane, uncl...
# 2   [animal, seasonal, people, wild, fruit, hunter...
# 3   [scrape, stone, wood, animal, skins, chop, cut...
# 4   [near, people, quality, stone, hunter, gathere...
# 5   [animals, pradesh, uttar, best, examples, grea...
# 6   [chapters, sites, different, things, tools, po...
# 7   [page, kurnool, caves, roast, meat, scare, awa...
# 8   [means, stone, period, middle, long, changes, ...
# 9   [warm, antelope, goat, food, habits, start, th...
# 10  [people, grass, animal, grew, probably, goat, ...
# 11  [animal, plant, gradual, largesize, grain, ago...
# 12  [time, weeks, people, began, large, clay, wate...
# 13  [animals, multiply, naturally, important, sour...
# 14  [scientists, study, burnt, animals, finds, inc...
# 15  [people, tools, things, food, different, palae...
# 16  [people, plain, burial, animals, include, mehr...
# 17  [like, painted, wild, horses, rituals, bison, ...
# 18  [sea, cowries, distances, catal, neolithic, si...
# 19  [colours, draw, rock, shelter, like, inner, wa...
#
#                                    Keybert-distilbert  \
# 1   [quickly, 150, trees, chennai, buses, trains, ...
# 2   [fruits, summer, rivers, bear, seasonal, eaten...
# 3   [fruit, trees, stone, arrows, bone, meat, hunt...
# 4   [easily, triangles, important, red, rivers, la...
# 5   [early, pradesh, uttar, best, southern, accura...
# 6   [chapters, learn, water, earth, different, bui...
# 7   [source, today, away, light, scare, page13, an...
# 8   [studying, greek, lengthy, tools, bone, 10000,...
# 9   [years, seasons, warm, habits, 12000, goat, an...
# 10  [shelters, women, dog, pig, goat, rice, barley...
# 11  [gentle, horns, pig, grow, goat, wheat, barley...
# 12  [birds, driving, weeks, dug, baskets, food, mo...
# 13  [apart, today, source, multiply, important, st...
# 14  [exciting, page13, blue, kashmir, burnt, herde...
# 15  [grain, weaving, mortars, palaeolithic, farmin...
# 16  [iran, relatives, pig, mehrgarh, page13, ferti...
# 17  [france, minerals, painting, 20000, 10000, rit...
# 18  [sea, famous, red, atlas, shells, cowries, syr...
# 19  [help, mix, years, live, page14, rock, 12000, ...
#
#                                    Keybert-paraphrase
# 1   [150, quickly, fly, buses, wondered, cousin, u...
# 2   [eggs, trees, reasons, moved, stayed, movement...
# 3   [bark, used, skins, trees, arrows, cut, firewo...
# 4   [important, shown, red, gatherers, lakes, ston...
# 5   [lived, best, southern, early, drawn, accuracy...
# 6   [people, learn, left, different, used, pots, c...
# 7   [away, today, map, suggests, animals, page13, ...
# 8   [changes, finds, microliths, lengthy, 12000, p...
# 9   [followed, antelope, turn, shift, 12000, seaso...
# 10  [wild, wheat, bearing, camps, plants, ancestor...
# 11  [preserved, domesticated, wild, different, hor...
# 12  [clay, huntergatherers, began, birds, cases, w...
# 13  [carefully, today, source, multiply, looked, r...
# 14  [blue, remains, includes, kashmir, scientists,...
# 15  [built, mortars, grains, shelter, kashmir, neo...
# 16  [burial, grow, include, goats, page13, sheep, ...
# 17  [performed, hunters, rituals, reindeer, france...
# 18  [famous, backs, carts, brought, settlement, me...
# 19  [mix, shelter, colours, painting, draw, tell, ...

# %%
df_para.to_csv('Chapter2_keywords.csv')

# %% [markdown]
# ###### -- Viral Doshi
